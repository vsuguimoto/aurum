# %% [markdown]
# # Introdução
#
# **Como usar as funções criadas?**
#
# Para importar o pacote *aurum*, primeiramente é preciso executar o snippet abaixo:
#
# ```
# import os
# import sys
#
# module_path = os.path.abspath(os.path.join('..'))
#
# if module_path not in sys.path:
#     sys.path.append(module_path)
# ```

# %%
# Antes de executar a célula tomamos um erro:
import aurum
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/sors/Documents/repos/aurum/aurum/notebooks/VS00-Introduction.ipynb Cell 2 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/sors/Documents/repos/aurum/aurum/notebooks/VS00-Introduction.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> # Antes de executar a célula tomamos um erro:
# ----> <a href='vscode-notebook-cell:/home/sors/Documents/repos/aurum/aurum/notebooks/VS00-Introduction.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import aurum
#
# ModuleNotFoundError: No module named 'aurum'

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Após a execução o módulo é importado
import aurum

# %% [markdown]
# Agora é só utilizar!
#
# Dica: se estiver utilizando o VSCode ao passar o mouse por cima da função, a documentação aparece com a descrição de cada função.

# %%
data = aurum.data.get_ohlcv('PETR4.SA')

# %%
data.head()
# Out:
#         Date      Open      High       Low     Close    Volume  Dividends  \
# 0 2017-01-02  7.373270  7.403488  7.353124  7.383342   7525700        0.0
# 1 2017-01-03  7.529399  7.881946  7.529399  7.806401  39947800        0.0
# 2 2017-01-04  7.781219  7.897056  7.710710  7.806401  37071700        0.0
# 3 2017-01-05  7.907126  8.012890  7.866835  7.932308  47586300        0.0
# 4 2017-01-06  7.947417  8.017927  7.806398  7.886981  25592000        0.0
#
#    Stock Splits  LEAK_Retorno  Alvo
# 0             0      0.043705     1
# 1             0     -0.001292     0
# 2             0      0.010217     1
# 3             0      0.009434     1
# 4             0      0.001275     1

# %%
data = aurum.ft.wiki_indicators('Petrobras', data)

# %%
data.head()
# Out:
#         Date      Open      High       Low     Close    Volume  Dividends  \
# 0 2017-01-02  7.373270  7.403488  7.353124  7.383342   7525700        0.0
# 1 2017-01-03  7.529399  7.881946  7.529399  7.806401  39947800        0.0
# 2 2017-01-04  7.781219  7.897056  7.710710  7.806401  37071700        0.0
# 3 2017-01-05  7.907126  8.012890  7.866835  7.932308  47586300        0.0
# 4 2017-01-06  7.947417  8.017927  7.806398  7.886981  25592000        0.0
#
#    Stock Splits  LEAK_Retorno  Alvo  WIKI_daily_views  WIKI_SMA_5  \
# 0             0      0.043705     1               230         NaN
# 1             0     -0.001292     0               295         NaN
# 2             0      0.010217     1               377         NaN
# 3             0      0.009434     1               277         NaN
# 4             0      0.001275     1               304       296.6
#
#    WIKI_SMA_5_Distance  WIKI_Yesterday_diff  WIKI_ROC_5
# 0                  NaN                -65.0         NaN
# 1                  NaN                -82.0         NaN
# 2                  NaN                100.0         NaN
# 3                  NaN                -27.0         NaN
# 4                  7.4               -200.0  102.494943
