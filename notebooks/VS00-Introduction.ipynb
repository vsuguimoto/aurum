# %% [markdown]
# # Introdução
#
# **Como usar as funções criadas?**
#
# Para importar o pacote *aurum*, primeiramente é preciso executar o snippet abaixo:
#
# ```
# import os
# import sys
#
# module_path = os.path.abspath(os.path.join('..'))
#
# if module_path not in sys.path:
#     sys.path.append(module_path)
# ```

# %%
# Antes de executar a célula tomamos um erro:
#import aurum

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Após a execução o módulo é importado
import aurum

# %% [markdown]
# Agora é só utilizar!
#
# Dica: se estiver utilizando o VSCode ao passar o mouse por cima da função, a documentação aparece com a descrição de cada função.

# %%
data = aurum.data.get_ohlcv('PETR4.SA')

# %%
data.head()
# Out:
#         Date      Open      High       Low     Close    Volume  Dividends  \
# 0 2017-01-02  7.373269  7.403487  7.353123  7.383341   7525700        0.0
# 1 2017-01-03  7.529398  7.881944  7.529398  7.806399  39947800        0.0
# 2 2017-01-04  7.781217  7.897054  7.710708  7.806399  37071700        0.0
# 3 2017-01-05  7.907126  8.012890  7.866835  7.932308  47586300        0.0
# 4 2017-01-06  7.947419  8.017928  7.806400  7.886982  25592000        0.0
#
#    Stock Splits  LEAK_Retorno  Alvo
# 0             0      0.043705     1
# 1             0     -0.001292     0
# 2             0      0.010217     1
# 3             0      0.009434     1
# 4             0      0.001275     1

# %%
data = aurum.ft.wiki_indicators('Petrobras', data)

# %%
data.head()
# Out:
#         Date      Open      High       Low     Close    Volume  Dividends  \
# 0 2017-01-02  7.373269  7.403487  7.353123  7.383341   7525700        0.0
# 1 2017-01-03  7.529398  7.881944  7.529398  7.806399  39947800        0.0
# 2 2017-01-04  7.781217  7.897054  7.710708  7.806399  37071700        0.0
# 3 2017-01-05  7.907126  8.012890  7.866835  7.932308  47586300        0.0
# 4 2017-01-06  7.947419  8.017928  7.806400  7.886982  25592000        0.0
#
#    Stock Splits  LEAK_Retorno  Alvo  WIKI_daily_views  WIKI_SMA_5  \
# 0             0      0.043705     1               230         NaN
# 1             0     -0.001292     0               295         NaN
# 2             0      0.010217     1               377         NaN
# 3             0      0.009434     1               277         NaN
# 4             0      0.001275     1               304       296.6
#
#    WIKI_SMA_5_Distance  WIKI_Yesterday_diff  WIKI_ROC_5
# 0                  NaN                -65.0         NaN
# ...

# %% [markdown]
# **Treinando um modelo**
#
# A seguir temos o treinamento completo de um modelo utilizando a função full_model_test

# %%
aurum.model_training.full_model_test('PETZ3.SA')
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# /home/sors/anaconda3/envs/data-science/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# DecisionTreeClassifier(max_depth=4, max_features='log2', min_samples_leaf=20,
#                        random_state=42)
