# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path)


import aurum

# %%
df = aurum.data.gerar_dataset('PETR4.SA', 'Petrobras')
# Out:
# /home/sors/Documents/repos/aurum/aurum/src/features/ft.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.ta.strategy(base_indicators)
# /home/sors/Documents/repos/aurum/aurum/src/features/ft.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.ta.strategy(base_indicators)
# /home/sors/Documents/repos/aurum/aurum/src/features/ft.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.dropna()
# Out:
#            Date       Open       High        Low      Close    Volume  \
# 4    2017-02-06   7.745962   7.791289   7.529397   7.534433  29686500
# 5    2017-02-07   7.604943   7.635161   7.403487   7.403487  29163900
# 6    2017-02-08   7.438742   7.604943   7.186923   7.604943  58912900
# 7    2017-02-09   7.645234   7.675452   7.534433   7.579761  33910300
# 8    2017-02-10   7.655307   7.871871   7.625088   7.846689  44467000
# ...         ...        ...        ...        ...        ...       ...
# 1315 2022-05-17  25.574942  25.677242  24.946529  24.961143  90914700
# 1316 2022-05-18  24.975759  25.253431  24.427725  24.551945  80986200
# 1317 2022-05-19  24.493489  25.056138  24.354655  24.968451  63983100
# 1318 2022-05-20  25.275351  25.450724  25.026909  25.450724  79589900
# 1319 2022-05-23  25.706472  26.532178  25.684552  26.451799  93807400
#
#       Dividends  Stock Splits  LEAK_Retorno  Alvo  ...  \
# 4           0.0             0      0.042254     1  ...
# ...
